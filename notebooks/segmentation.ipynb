# %%
import sys
import os
os.chdir('/home/jetske22/sign_cas/Sign-Language-Thesis-main/')
# %load_ext autoreload
# %autoreload 2

# %%
from dataset.preparation.segment_validation import *
run_inter_annotator_agreement(['example'], ['segmenter', 'annotator'], tier_names=['Sentence S2'], frame_range=10)
# Out:
# 43
# 51
# COUNTING with annotation.start gives precision:  0.7209302325581395 Recall:  0.6078431372549019 Count:  31
# Krippendorff total:  0.8559285570683102

# %%
from dataset.preparation.segment_validation import *
run_inter_annotator_agreement(['example'], ['segmenter', 'annotator'], tier_names=['Gloss S2'], frame_range=3)
# Out:
# 206
# 194
# COUNTING with annotation.start gives precision:  0.7815533980582524 Recall:  0.8298969072164949 Count:  161
# 2024-03-12 14:26:06.179428: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-12 14:26:07.012464: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-12 14:26:07.013442: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-12 14:26:07.171425: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
